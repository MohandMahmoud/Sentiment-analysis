# %% [markdown]
# # **Import Lib**

# %%
import os
import string
import nltk
from tensorflow import keras
import numpy as np
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %% [markdown]
# # **Nltk,Stemmer,Lemmatizer --> Download**

# %%
# Download NLTK resources if not already downloaded
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')


# Initialize stemmer and lemmatizer
stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\ziad
# [nltk_data]     nagi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\ziad
# [nltk_data]     nagi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\ziad
# [nltk_data]     nagi\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # **Preprocessing**

# %%
def preprocess_text(text):
    # Convert to lowercase
    # text = text.lower()
    # Tokenization
    sentences = nltk.sent_tokenize(text)
    preprocessed_sentences = []
    for sentence in sentences:
        # Remove punctuation
        sentence = sentence.translate(str.maketrans('', '', string.punctuation))
        # Tokenization
        tokens = nltk.word_tokenize(sentence)
        # Remove stopwords
        stop_words = set(stopwords.words('english'))
        tokens = [word for word in tokens if word not in stop_words]
        # Stemming
        stemmer = PorterStemmer()
        stemmed_tokens = [stemmer.stem(word) for word in tokens]
        # Lemmatization
        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(word) for word in stemmed_tokens]
        # Join tokens back into a single string
        preprocessed_sentence = ' '.join(lemmatized_tokens)
        preprocessed_sentences.append(preprocessed_sentence)
    return preprocessed_sentences

# %% [markdown]
# # **Load Files**

# %%
# Define a function to load text files from a directory and preprocess them
def load_text_files(directory):
    texts = []
    labels = []
    for label in ['pos', 'neg']:
        label_dir = os.path.join(directory, label)
        for filename in os.listdir(label_dir):
            with open(os.path.join(label_dir, filename), 'r', encoding='utf-8') as file:
                text = file.read()
                preprocessed_text = preprocess_text(text)
                texts.append(preprocessed_text)
                labels.append(label)
    return texts, labels

# %%
# Assuming your positive and negative processed reviews are stored in directories 'positive' and 'negative'
data_directory = 'Dataset/txt_sentoken'
texts, labels = load_text_files(data_directory)

# %% [markdown]
# # **Encoding**

# %%
# Encoding labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# %% [markdown]
# # **Split Data**

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(texts, labels_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# # **TF-IDF --> Feature Extraction**

# %%
# Text vectorization using TF-IDF
tfidf_vectorizer = TfidfVectorizer(max_features=5000,ngram_range=(1,2))
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 3
#       1 # Text vectorization using TF-IDF
#       2 tfidf_vectorizer = TfidfVectorizer(max_features=5000,ngram_range=(1,2))
# ----> 3 X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
#       4 X_test_tfidf = tfidf_vectorizer.transform(X_test)
#
# File c:\ProgramData\anaconda3\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py:2138, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2131 self._check_params()
#    2132 self._tfidf = TfidfTransformer(
#    2133     norm=self.norm,
#    2134     use_idf=self.use_idf,
#    2135     smooth_idf=self.smooth_idf,
#    2136     sublinear_tf=self.sublinear_tf,
#    2137 )
# -> 2138 X = super().fit_transform(raw_documents)
#    2139 self._tfidf.fit(X)
#    2140 # X is already a transformed view of raw_documents so
#    2141 # we set copy to False
#
# File c:\ProgramData\anaconda3\envs\tf\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File c:\ProgramData\anaconda3\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py:1389, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1381             warnings.warn(
#    1382                 "Upper case characters found in"
#    1383                 " vocabulary while 'lowercase'"
#    1384                 " is True. These entries will not"
#    1385                 " be matched with any documents"
#    1386             )
#    1387             break
# -> 1389 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1391 if self.binary:
#    1392     X.data.fill(1)
#
# File c:\ProgramData\anaconda3\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py:1276, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1274 for doc in raw_documents:
#    1275     feature_counter = {}
# -> 1276     for feature in analyze(doc):
#    1277         try:
#    1278             feature_idx = vocabulary[feature]
#
# File c:\ProgramData\anaconda3\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py:110, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     108 else:
#     109     if preprocessor is not None:
# --> 110         doc = preprocessor(doc)
#     111     if tokenizer is not None:
#     112         doc = tokenizer(doc)
#
# File c:\ProgramData\anaconda3\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py:68, in _preprocess(doc, accent_function, lower)
#      49 """Chain together an optional series of text preprocessing steps to
#      50 apply to a document.
#      51
#    (...)
#      65     preprocessed string
#      66 """
#      67 if lower:
# ---> 68     doc = doc.lower()
#      69 if accent_function is not None:
#      70     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# # **SVM**

# %%
# Model training
svm_model = SVC(kernel='linear')
svm_model.fit(X_train_tfidf, y_train)

# Model evaluation
y_pred = svm_model.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print("SVM Accuracy:", accuracy)
print("Confusion Matrix:")
print(conf_matrix)

# Visualization
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# SVM Accuracy: 0.83
# Confusion Matrix:
# [[168  33]
#  [ 35 164]]

# %% [markdown]
# # **ML Models**

# %%
# Initialize classifiers
classifiers = {
    'SVM': SVC(kernel='linear'),
    'Naive Bayes': MultinomialNB(),
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'K-Nearest Neighbors': KNeighborsClassifier()
}

# %%
# Train and evaluate classifiers
train_accuracies = []
test_accuracies = []
for name, classifier in classifiers.items():
    classifier.fit(X_train_tfidf, y_train)
    train_accuracy = classifier.score(X_train_tfidf, y_train)
    test_accuracy = classifier.score(X_test_tfidf, y_test)
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)
    print(f'{name} - Training Accuracy: {train_accuracy*100:.2f}%      ,     Testing Accuracy: {test_accuracy*100:.2f}%')
# Out:
# SVM - Training Accuracy: 98.31%      ,     Testing Accuracy: 83.00%
# Naive Bayes - Training Accuracy: 92.62%      ,     Testing Accuracy: 80.75%
# Logistic Regression - Training Accuracy: 95.81%      ,     Testing Accuracy: 83.00%
# Random Forest - Training Accuracy: 100.00%      ,     Testing Accuracy: 76.75%
# Gradient Boosting - Training Accuracy: 97.81%      ,     Testing Accuracy: 76.00%
# K-Nearest Neighbors - Training Accuracy: 80.06%      ,     Testing Accuracy: 66.50%

# %%
# Plotting the bar chart for training and testing accuracies
plt.figure(figsize=(10, 6))
plt.bar(classifiers.keys(), train_accuracies, color='blue', label='Training Accuracy')
plt.bar(classifiers.keys(), test_accuracies, color='red', label='Testing Accuracy')
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.title('Training and Testing Accuracies of Classifiers')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Plotting confusion matrix using SVM (best performing classifier)
best_classifier = classifiers['SVM']
y_pred = best_classifier.predict(X_test_tfidf)
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # **DL Model 1**

# %%
# Deep Learning Model
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train_tfidf.shape[1],)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train_tfidf.toarray(), y_train, epochs=30, batch_size=32, validation_split=0.2)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_tfidf.toarray(), y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")


# Plot training history
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/30
# 40/40 [==============================] - 2s 9ms/step - loss: 0.6856 - accuracy: 0.5898 - val_loss: 0.6706 - val_accuracy: 0.7312
# Epoch 2/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.5835 - accuracy: 0.8164 - val_loss: 0.5038 - val_accuracy: 0.8469
# Epoch 3/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.3325 - accuracy: 0.9031 - val_loss: 0.3608 - val_accuracy: 0.8562
# Epoch 4/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1455 - accuracy: 0.9703 - val_loss: 0.3419 - val_accuracy: 0.8438
# Epoch 5/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9828 - val_loss: 0.3744 - val_accuracy: 0.8469
# Epoch 6/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0363 - accuracy: 0.9977 - val_loss: 0.4053 - val_accuracy: 0.8375
# Epoch 7/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9969 - val_loss: 0.4095 - val_accuracy: 0.8594
# Epoch 8/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9992 - val_loss: 0.4345 - val_accuracy: 0.8344
# Epoch 9/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4517 - val_accuracy: 0.8438
# Epoch 10/30
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9992 - val_loss: 0.4723 - val_accuracy: 0.8313
# Epoch 11/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9992 - val_loss: 0.5142 - val_accuracy: 0.8344
# Epoch 12/30
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5009 - val_accuracy: 0.8313
# Epoch 13/30
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.5531 - val_accuracy: 0.8281
# Epoch 14/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5347 - val_accuracy: 0.8375
# Epoch 15/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.5395 - val_accuracy: 0.8375
# Epoch 16/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.8313
# Epoch 17/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5569 - val_accuracy: 0.8375
# Epoch 18/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.8344
# Epoch 19/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5642 - val_accuracy: 0.8406
# Epoch 20/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5712 - val_accuracy: 0.8438
# Epoch 21/30
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5823 - val_accuracy: 0.8375
# Epoch 22/30
# 40/40 [==============================] - 0s 6ms/step - loss: 9.8031e-04 - accuracy: 1.0000 - val_loss: 0.5754 - val_accuracy: 0.8438
# Epoch 23/30
# 40/40 [==============================] - 0s 6ms/step - loss: 9.9721e-04 - accuracy: 1.0000 - val_loss: 0.5920 - val_accuracy: 0.8469
# Epoch 24/30
# 40/40 [==============================] - 0s 5ms/step - loss: 7.8326e-04 - accuracy: 1.0000 - val_loss: 0.5888 - val_accuracy: 0.8375
# Epoch 25/30
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5993 - val_accuracy: 0.8281
# Epoch 26/30
# 40/40 [==============================] - 0s 6ms/step - loss: 8.5075e-04 - accuracy: 1.0000 - val_loss: 0.6308 - val_accuracy: 0.8438
# Epoch 27/30
# 40/40 [==============================] - 0s 5ms/step - loss: 6.4742e-04 - accuracy: 1.0000 - val_loss: 0.6255 - val_accuracy: 0.8469
# Epoch 28/30
# 40/40 [==============================] - 0s 6ms/step - loss: 6.7982e-04 - accuracy: 1.0000 - val_loss: 0.6302 - val_accuracy: 0.8469
# Epoch 29/30
# 40/40 [==============================] - 0s 6ms/step - loss: 6.8912e-04 - accuracy: 1.0000 - val_loss: 0.6619 - val_accuracy: 0.8469
# Epoch 30/30
# 40/40 [==============================] - 0s 5ms/step - loss: 6.7560e-04 - accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.8375
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8411 - accuracy: 0.8325
# Test Accuracy: 83.25%

# %%
# Plot confusion matrix
y_pred = np.round(model.predict(X_test_tfidf.toarray())).astype(int)
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %% [markdown]
# # **DL Model 2**

# %%
# Define the second deep learning model
model2 = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(X_train_tfidf.shape[1],)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

model2.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

# %%
# Train the second model
history2 = model2.fit(X_train_tfidf.toarray(), y_train, epochs=30, batch_size=32, validation_split=0.2)

# Evaluate the second model
test_loss2, test_accuracy2 = model2.evaluate(X_test_tfidf.toarray(), y_test)
print(f"Test Accuracy (Model 2): {test_accuracy2 * 100:.2f}%")

# Plot training history for both models
plt.plot(history.history['accuracy'], label='Model 1 Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Model 1 Validation Accuracy')
plt.plot(history2.history['accuracy'], label='Model 2 Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Model 2 Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/30
# 40/40 [==============================] - 1s 12ms/step - loss: 0.6795 - accuracy: 0.6195 - val_loss: 0.6403 - val_accuracy: 0.8313
# Epoch 2/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.4796 - accuracy: 0.8664 - val_loss: 0.4169 - val_accuracy: 0.8313
# Epoch 3/30
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1680 - accuracy: 0.9539 - val_loss: 0.3455 - val_accuracy: 0.8562
# Epoch 4/30
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0503 - accuracy: 0.9914 - val_loss: 0.3865 - val_accuracy: 0.8375
# Epoch 5/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9977 - val_loss: 0.4408 - val_accuracy: 0.8438
# Epoch 6/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.4543 - val_accuracy: 0.8281
# Epoch 7/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4656 - val_accuracy: 0.8344
# Epoch 8/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.8344
# Epoch 9/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.5105 - val_accuracy: 0.8313
# Epoch 10/30
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5244 - val_accuracy: 0.8344
# Epoch 11/30
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5355 - val_accuracy: 0.8344
# Epoch 12/30
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.8344
# Epoch 13/30
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6008 - val_accuracy: 0.8250
# Epoch 14/30
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5618 - val_accuracy: 0.8375
# Epoch 15/30
# 40/40 [==============================] - 0s 4ms/step - loss: 5.3501e-04 - accuracy: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.8406
# Epoch 16/30
# 40/40 [==============================] - 0s 4ms/step - loss: 4.9210e-04 - accuracy: 1.0000 - val_loss: 0.5791 - val_accuracy: 0.8344
# Epoch 17/30
# 40/40 [==============================] - 0s 5ms/step - loss: 4.9296e-04 - accuracy: 1.0000 - val_loss: 0.5915 - val_accuracy: 0.8344
# Epoch 18/30
# 40/40 [==============================] - 0s 5ms/step - loss: 4.7507e-04 - accuracy: 1.0000 - val_loss: 0.6066 - val_accuracy: 0.8375
# Epoch 19/30
# 40/40 [==============================] - 0s 5ms/step - loss: 4.1310e-04 - accuracy: 1.0000 - val_loss: 0.6098 - val_accuracy: 0.8406
# Epoch 20/30
# 40/40 [==============================] - 0s 5ms/step - loss: 3.0121e-04 - accuracy: 1.0000 - val_loss: 0.6209 - val_accuracy: 0.8375
# Epoch 21/30
# 40/40 [==============================] - 0s 5ms/step - loss: 3.9435e-04 - accuracy: 1.0000 - val_loss: 0.6316 - val_accuracy: 0.8406
# Epoch 22/30
# 40/40 [==============================] - 0s 6ms/step - loss: 3.5627e-04 - accuracy: 1.0000 - val_loss: 0.6268 - val_accuracy: 0.8406
# Epoch 23/30
# 40/40 [==============================] - 0s 5ms/step - loss: 3.0192e-04 - accuracy: 1.0000 - val_loss: 0.6315 - val_accuracy: 0.8438
# Epoch 24/30
# 40/40 [==============================] - 0s 4ms/step - loss: 7.1997e-04 - accuracy: 1.0000 - val_loss: 0.6959 - val_accuracy: 0.8188
# Epoch 25/30
# 40/40 [==============================] - 0s 5ms/step - loss: 3.0418e-04 - accuracy: 1.0000 - val_loss: 0.6506 - val_accuracy: 0.8344
# Epoch 26/30
# 40/40 [==============================] - 0s 4ms/step - loss: 1.7452e-04 - accuracy: 1.0000 - val_loss: 0.6586 - val_accuracy: 0.8344
# Epoch 27/30
# 40/40 [==============================] - 0s 4ms/step - loss: 1.9191e-04 - accuracy: 1.0000 - val_loss: 0.6714 - val_accuracy: 0.8406
# Epoch 28/30
# 40/40 [==============================] - 0s 5ms/step - loss: 2.2484e-04 - accuracy: 1.0000 - val_loss: 0.6635 - val_accuracy: 0.8344
# Epoch 29/30
# 40/40 [==============================] - 0s 4ms/step - loss: 1.7589e-04 - accuracy: 1.0000 - val_loss: 0.6690 - val_accuracy: 0.8344
# Epoch 30/30
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2687e-04 - accuracy: 1.0000 - val_loss: 0.6761 - val_accuracy: 0.8406
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8406 - accuracy: 0.8375
# Test Accuracy (Model 2): 83.75%

# %% [markdown]
# # **Compare 2 DL Models**

# %%
# Plot confusion matrix for both models
y_pred2 = np.round(model2.predict(X_test_tfidf.toarray())).astype(int)
conf_matrix2 = confusion_matrix(y_test, y_pred2)

plt.figure(figsize=(15, 6))
plt.subplot(1, 2, 1)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix (Model 1)')

plt.subplot(1, 2, 2)
sns.heatmap(conf_matrix2, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix (Model 2)')

plt.tight_layout()
plt.show()
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %% [markdown]
# # **Print Samples From Prediction**

# %%
# Print predictions for some sample texts from the testing set
print("Sample Predictions for Testing Sentiments:")
for i in range(5):
    sample_text = X_test[i]
    sample_label = label_encoder.inverse_transform([y_test[i]])[0]
    sample_text_tfidf = tfidf_vectorizer.transform([sample_text])
    for name, classifier in classifiers.items():
        predicted_label = label_encoder.inverse_transform(classifier.predict(sample_text_tfidf))[0]
        print(f"Sample {i+1} ({sample_label}): {name} Predicted Sentiment: {predicted_label}")

# Identify the best-performing model
best_model_name = max(classifiers, key=lambda k: classifiers[k].score(X_test_tfidf, y_test))
print("\nBest Performing Model on Testing Set:", best_model_name)
# Out:
# Sample Predictions for Testing Sentiments:
# Sample 1 (neg): SVM Predicted Sentiment: neg
# Sample 1 (neg): Naive Bayes Predicted Sentiment: neg
# Sample 1 (neg): Logistic Regression Predicted Sentiment: neg
# Sample 1 (neg): Random Forest Predicted Sentiment: neg
# Sample 1 (neg): Gradient Boosting Predicted Sentiment: neg
# Sample 1 (neg): K-Nearest Neighbors Predicted Sentiment: neg
# Sample 2 (pos): SVM Predicted Sentiment: pos
# Sample 2 (pos): Naive Bayes Predicted Sentiment: pos
# Sample 2 (pos): Logistic Regression Predicted Sentiment: pos
# Sample 2 (pos): Random Forest Predicted Sentiment: neg
# Sample 2 (pos): Gradient Boosting Predicted Sentiment: neg
# Sample 2 (pos): K-Nearest Neighbors Predicted Sentiment: pos
# Sample 3 (neg): SVM Predicted Sentiment: neg
# Sample 3 (neg): Naive Bayes Predicted Sentiment: pos
# Sample 3 (neg): Logistic Regression Predicted Sentiment: pos
# Sample 3 (neg): Random Forest Predicted Sentiment: pos
# Sample 3 (neg): Gradient Boosting Predicted Sentiment: neg
# Sample 3 (neg): K-Nearest Neighbors Predicted Sentiment: pos
# Sample 4 (pos): SVM Predicted Sentiment: pos
# Sample 4 (pos): Naive Bayes Predicted Sentiment: pos
# Sample 4 (pos): Logistic Regression Predicted Sentiment: pos
# Sample 4 (pos): Random Forest Predicted Sentiment: pos
# Sample 4 (pos): Gradient Boosting Predicted Sentiment: pos
# Sample 4 (pos): K-Nearest Neighbors Predicted Sentiment: pos
# Sample 5 (neg): SVM Predicted Sentiment: neg
# Sample 5 (neg): Naive Bayes Predicted Sentiment: neg
# Sample 5 (neg): Logistic Regression Predicted Sentiment: neg
# Sample 5 (neg): Random Forest Predicted Sentiment: neg
# Sample 5 (neg): Gradient Boosting Predicted Sentiment: pos
# Sample 5 (neg): K-Nearest Neighbors Predicted Sentiment: neg
#
# Best Performing Model on Testing Set: SVM
